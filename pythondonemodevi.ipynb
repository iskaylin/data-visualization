# %% [markdown]
# <a href="https://colab.research.google.com/github/iskaylin/data-visualization/blob/main/pythondonemodevi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # visualization
import plotly.express as px # create entire figure at once
import seaborn as sns #visualization
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
df1=df.copy()
df1.rename(columns={' Income ':'Income'}, inplace = True)
df1["Income"]=df1["Income"].str.replace("$","")
df1["Income"]=df1["Income"].str.replace(",","")
df1["Income"]=df1["Income"].astype(float)
sns.histplot(df1['Income'],kde=30);

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
#copy data 
df1=df.copy()
df1['Kids_Teen_at_home'] = df1['Kidhome'] + df1['Teenhome']
df1['Kids_Teen_at_home'] = df1['Kidhome'] + df1['Teenhome']
sns.boxplot(x='Year_Birth', data=df1);

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
#copy data 
df1=df.copy()

plt.grid();
plt.title('Eğitim',size=15);
sns.countplot(x = df1['Education'],palette = 'rocket_r');

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
#copy data 
df1=df.copy()
m = df1['Marital_Status'].value_counts().to_frame('Count')
sns.set_palette('gist_stern')
plt.figure(figsize = (6, 6))
plt.pie(m['Count'], labels = m.index, explode = (0.1, 0, 0, 0, 0, 1, 2.5, 4), shadow = True, autopct = '%1.1f%%')
plt.show()

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
#copy data 
df1=df.copy()
cnt = 0
max_in_row = 1
for x in Total_Spent:
    plt.figure(cnt//max_in_row, figsize=(25,8))
    plt.subplot(1, max_in_row, (cnt)%max_in_row + 1)
    plt.title(x, fontsize=20)
    plt.xticks(fontsize=16)
    plt.yticks(fontsize=16)
    plt.xlabel(x, fontsize=16)
    plt.ylabel('Density', fontsize=16)
    sns.kdeplot(data=df1, x=x, hue="Marital_Status", fill=True, common_norm=False, alpha=.5, linewidth=0);
    cnt += 1
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning:
#
# Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#
# ...

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
df2=df1.copy()
sns.set()
df2.set_index('Dt_Customer',inplace=True)
df2[['NumStorePurchases']].plot(figsize=(40,10));

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
pie1 = df1.filter(regex='Cmp').sum().sort_values(ascending=False)
pie1 = pd.DataFrame(pie1)
pie1 = pie1.reset_index()
pie1
import plotly.express as px
fig = px.pie(pie1,names='index',values=0, color_discrete_sequence=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3f81b251-5e74-40ec-94f3-98d74151d23a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f81b251-5e74-40ec-94f3-98d74151d23a")) {
#                     Plotly.newPlot(
#                         '3f81b251-5e74-40ec-94f3-98d74151d23a',
# ...

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)

pie3 = df1.filter(regex='Num').sum().sort_values(ascending=False)
pie3 = pie3.drop(labels='NumWebVisitsMonth')
pie3 = pd.DataFrame(pie3)
pie3 = pie3.reset_index()
pie3

fig = px.pie(pie3,names='index',values=0, color_discrete_sequence=px.colors.sequential.Reds)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="09694290-2797-4c87-924f-e0e20edd7466" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("09694290-2797-4c87-924f-e0e20edd7466")) {
#                     Plotly.newPlot(
#                         '09694290-2797-4c87-924f-e0e20edd7466',
# ...

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
df['totalPurchases']=df['NumWebPurchases']+df['NumDealsPurchases']+df['NumCatalogPurchases']+df['NumStorePurchases']
# add on column for total amount spent
mnt_columns = [col for col in df.columns if 'Mnt' in col]
df['totalMnt'] = df[mnt_columns].sum(axis=1)
df_to_plot = df.drop(columns=['ID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain', "NumDealsPurchases","NumStorePurchases","NumWebPurchases","NumCatalogPurchases",'totalMnt', 'totalPurchases']).select_dtypes(include=np.number)

# subplots
df_to_plot.plot(subplots=True, layout=(3,6), kind='box', figsize=(12,14), patch_artist=True)
plt.subplots_adjust(wspace=0.8)

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
deals = df1[df1['NumDealsPurchases'] < 11].copy()
web = df1[df1['NumWebPurchases'] < 11].copy()
catalog = df1[df1['NumCatalogPurchases'] < 11].copy()
store = df1[df1['NumStorePurchases'] < 11].copy()

deals.plot(kind='hist', x="Recency", y="NumDealsPurchases", bins=20, colormap='Set1')

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)

fig = px.histogram(df1, 
                   x='Income', 
                   marginal='box', 
                   color='Kidhome', 
                 
                   color_discrete_sequence=['limegreen', 'honeydew'], 
                   title='Gelir seviyesine göre küçük çocuk dağılımı')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="99f3ecd9-30e7-46d1-89fe-ae1e41f3145d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("99f3ecd9-30e7-46d1-89fe-ae1e41f3145d")) {
#                     Plotly.newPlot(
#                         '99f3ecd9-30e7-46d1-89fe-ae1e41f3145d',
# ...

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
sns.countplot(data=df,y='Education',hue='Response',palette='PiYG')
plt.title('Müşterilerin Tepkilerine göre Eğitim seviyeleri')
plt.figure(figsize=(20,10))
plt.show()

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
sns.boxplot(y=df['Recency'])

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
plt.figure(figsize=(6,3), dpi=100)

x = df['Kidhome'].value_counts().index
y = df['Kidhome'].value_counts().values

sns.barplot(x=x, y=y, order=x, color='lightblue', alpha=.5)

plt.title('Müşterilerin sahip oldukları çocuk sayıları', fontsize=20)
plt.xlabel('Çocuk sayısı', fontsize=15)
plt.ylabel('sıklık', fontsize=15)

plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
plt.figure(figsize = (8, 6))
purchase_source =  pd.DataFrame(df[['NumWebPurchases', 'NumStorePurchases', 'NumCatalogPurchases', 'NumDealsPurchases']].agg([sum]))

sns.barplot(x = purchase_source.T.index, y = purchase_source.T['sum'], palette = 'husl')
plt.gca().set_xticklabels(['Web', 'Store', 'Catalog', 'Deals'])
plt.xlabel('Satın Alma Kaynakları')
plt.ylabel('Satın Alma')
plt.show()

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
MntFishProducts = df.groupby('Education').sum()['MntFishProducts'].reset_index()
MntFishProducts.plot(x = 'Education' , y = 'MntFishProducts' , kind = 'bar')

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
mnt_cols = [col for col in df.columns if 'Mnt' in col]
spending = df[mnt_cols].mean(axis=0)
spending.plot(kind='bar',figsize=(10,5))
plt.ylabel('Müşterilerin tercih ettikleri ürünler')
plt.show()

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
plt.title('Eğitim Düzeyi',size=15);
sns.countplot(df['Education'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
plt.figure(figsize=(25,5))
sns.boxplot(x=df['Education'], y=df['MntFishProducts'], hue=df['Marital_Status'])

# %%
csv_file='Marketing.csv'
df = pd.read_csv(csv_file)
label = 'Beğenildi','Beğenilmedi'
plt.pie([len(df1['Response'][df1['Response']==1]),len(df1['Response'][df1['Response']==0])],labels=label,autopct='%1.1f%%',shadow=True, startangle=90)
plt.title('SON KAMPANYA');
